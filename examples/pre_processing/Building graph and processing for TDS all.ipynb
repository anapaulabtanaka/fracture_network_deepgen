# %% [markdown]
# # Generation of graph data from existing graphs

# %%
import geopandas as gpd
from shapely.geometry import LineString, MultiLineString
import networkx as nx
import matplotlib.pyplot as plt
import os
import pickle

# %% [markdown]
# ## Creating a graph from the fracture network

# %%
print(os.getcwd())
# Out:
# C:\Users\burgoaa\Desktop\python\frac_deepgen

# %%
# Read fracture interpretation and transform to graphs
graphs = []
folder = 'data/shapefile'
files = sorted(f for f in os.listdir(folder) if f.endswith('.shp'))
precision = 5 #decimals

for f_name in files:
    print(f_name)
    gdf = gpd.read_file (os.path.join(folder, f_name))
    G = nx.Graph()
    coord_to_label = {}
    label_counter = 0
    edges = []

    for geom in gdf.geometry:
        if isinstance(geom, LineString):
            lines = [geom]
        elif isinstance(geom, MultiLineString):
            lines = list(geom.geoms)
        else:
            continue

        for line in lines:
            coords = [tuple(round(c, precision) for c in pt) for pt in line.coords]
            labels = []

        for coord in coords:
            if coord not in coord_to_label:
                coord_to_label[coord] = label_counter
                x, y = coord[:2]
                G.add_node(label_counter, pos=(x,y))
                label_counter += 1
            labels.append(coord_to_label[coord])

        edges.extend(zip(labels[:-1], labels[1:]))
    
    G.add_edges_from(edges)
    G.remove_edges_from(nx.selfloop_edges(G))
    pos = nx.get_node_attributes(G, 'pos')
    graphs.append(G)
# Out:
# Area1.shp
# Area2.shp
# Area3.shp
# Area4.shp
# Area5.shp
# Coastal_Bedrock_Geology_snp.shp
# Flato_20m_1.shp
# Getaberget_20m_1.shp
# Getaberget_20m_2_1.shp
# Getaberget_20m_2_2.shp
# Getaberget_20m_3_3.shp
# Getaberget_20m_4_1.shp
# Getaberget_20m_4_2.shp
# Getaberget_20m_5.shp
# Getaberget_20m_7_1.shp
# Getaberget_20m_7_2.shp
# Getaberget_20m_8.shp
# Getaberget_20m_9.shp
# Havsvidden_20m.shp
# Manual_NE1.shp
# Manual_NE2.shp
# Manual_SW1.shp
# Manual_SW2.shp
# Manual_SW3.shp
# Mineral_mtns.shp
# North.shp
# Segelskar_20m_1.shp
# Shapefile_South.shp
# South_1.shp
# Station_Mid1.shp
# Station_Mid2.shp
# Station_Mid3.shp
# Station_North1.shp
# Station_South1.shp
# Station_South2.shp
# Station_South3.shp
# apodi2.shp
# apodi3.shp
# apodi4.shp
# braided.shp
# brick.shp
# diamond.shp
# dix-sept1.shp
# en_north.shp
# en_south.shp
# frac_graph_1000.shp
# fractures.shp
# fractures_projected_snp.shp
# hexagonon.shp
# hhs.shp
# inv.shp
# off_sebrazil.shp
# out_braided.shp
# out_brick.shp
# out_diamond.shp
# out_hexagonon.shp
# out_pavement.shp
# out_polygonal.shp
# out_square.shp
# out_star.shp
# out_stochastic.shp
# pavement.shp
# polygonal.shp
# simplified17.shp
# square.shp
# star.shp
# stochastic.shp
# tcfr.shp
# tsan_D.shp
# tsan_fractures.shp

# %%
print(graphs[10].nodes(data=True))
# Out:
# [(0, {'pos': (104861.23561, 6719696.27875)}), (1, {'pos': (104860.69761, 6719696.4917)}), (2, {'pos': (104855.93265, 6719695.64547)}), (3, {'pos': (104855.75052, 6719695.20975)}), (4, {'pos': (104848.46876, 6719690.97022)}), (5, {'pos': (104848.27313, 6719690.73901)}), (6, {'pos': (104847.67909, 6719690.4546)}), (7, {'pos': (104847.58942, 6719690.26405)}), (8, {'pos': (104845.55791, 6719688.72711)}), (9, {'pos': (104845.78628, 6719688.83359)}), (10, {'pos': (104843.62867, 6719688.43709)}), (11, {'pos': (104843.78699, 6719688.45811)}), (12, {'pos': (104862.2857, 6719699.28539)}), (13, {'pos': (104862.34945, 6719699.93407)}), (14, {'pos': (104852.74247, 6719686.73342)}), (15, {'pos': (104852.5155, 6719686.54568)}), (16, {'pos': (104858.42532, 6719680.0587)}), (17, {'pos': (104858.23387, 6719680.09456)}), (18, {'pos': (104866.58011, 6719692.73971)}), (19, {'pos': (104866.39749, 6719692.54606)}), (20, {'pos': (104864.02299, 6719694.44548)}), (21, {'pos': (104863.85067, 6719694.33339)}), (22, {'pos': (104861.78552, 6719694.97017)}), (23, {'pos': (104861.86538, 6719695.10607)}), (24, {'pos': (104860.61762, 6719691.17233)}), (25, {'pos': (104860.61145, 6719691.48016)}), (26, {'pos': (104874.46569, 6719679.12574)}), (27, {'pos': (104874.03137, 6719679.09772)}), (28, {'pos': (104868.35339, 6719699.66801)}), (29, {'pos': (104868.39876, 6719699.90552)}), (30, {'pos': (104872.6019, 6719703.30673)}), (31, {'pos': (104872.54586, 6719702.95179)}), (32, {'pos': (104883.7689, 6719708.25709)}), (33, {'pos': (104883.79826, 6719708.59868)}), (34, {'pos': (104878.86307, 6719688.01782)}), (35, {'pos': (104878.33151, 6719688.15675)}), (36, {'pos': (104876.18191, 6719695.44486)}), (37, {'pos': (104875.99777, 6719695.6797)}), (38, {'pos': (104863.86784, 6719689.95261)}), (39, {'pos': (104863.81874, 6719689.95727)}), (40, {'pos': (104863.33298, 6719691.54461)}), (41, {'pos': (104862.93535, 6719691.12296)}), (42, {'pos': (104861.7683, 6719682.76335)}), (43, {'pos': (104861.22207, 6719683.03292)}), (44, {'pos': (104861.86812, 6719679.49541)}), (45, {'pos': (104861.29146, 6719679.43957)}), (46, {'pos': (104856.91085, 6719674.76008)}), (47, {'pos': (104857.01493, 6719674.88551)}), (48, {'pos': (104846.41952, 6719680.1628)}), (49, {'pos': (104846.48897, 6719679.87943)}), (50, {'pos': (104852.31809, 6719678.28805)}), (51, {'pos': (104851.78436, 6719678.22133)}), (52, {'pos': (104852.85983, 6719678.30139)}), (53, {'pos': (104852.73707, 6719678.34943)}), (54, {'pos': (104854.50105, 6719678.16929)}), (55, {'pos': (104854.25287, 6719678.15995)}), (56, {'pos': (104851.37872, 6719675.43258)}), (57, {'pos': (104850.99977, 6719675.55)}), (58, {'pos': (104846.58908, 6719669.72158)}), (59, {'pos': (104846.37097, 6719670.2373)}), (60, {'pos': (104865.94827, 6719671.76851)}), (61, {'pos': (104865.77213, 6719671.77919)}), (62, {'pos': (104860.27069, 6719695.24337)}), (63, {'pos': (104860.66966, 6719695.23003)}), (64, {'pos': (104856.82996, 6719695.65788)}), (65, {'pos': (104857.0603, 6719695.52625)}), (66, {'pos': (104880.35335, 6719694.43687)}), (67, {'pos': (104880.07748, 6719694.46412)}), (68, {'pos': (104866.72803, 6719661.55929)}), (69, {'pos': (104866.92766, 6719661.91716)}), (70, {'pos': (104871.38259, 6719671.38062)}), (71, {'pos': (104871.2649, 6719671.20129)}), (72, {'pos': (104863.81554, 6719672.50986)}), (73, {'pos': (104863.58717, 6719672.5547)}), (74, {'pos': (104862.64146, 6719655.50957)}), (75, {'pos': (104862.49015, 6719654.99399)}), (76, {'pos': (104871.44564, 6719655.87384)}), (77, {'pos': (104871.29713, 6719655.77017)}), (78, {'pos': (104880.39937, 6719659.85737)}), (79, {'pos': (104880.03854, 6719659.51632)}), (80, {'pos': (104876.0651, 6719658.9834)}), (81, {'pos': (104876.06699, 6719659.26998)}), (82, {'pos': (104884.61652, 6719664.34772)}), (83, {'pos': (104885.20776, 6719664.64754)}), (84, {'pos': (104883.18644, 6719666.20789)}), (85, {'pos': (104883.03054, 6719665.78379)}), (86, {'pos': (104883.55071, 6719667.26148)}), (87, {'pos': (104883.79831 ...

# %%
#Export graph as pickle with attributes
for i, graph in enumerate(graphs):
    output = f'data/tds_rev/G{i}.pickle'
    with open (output, 'wb') as f:
        pickle.dump(graph, f)

# %%
# Identify largest connected components from simplified graphs
largest = []
for graph in graphs:
    print(graph)
    all_components = list(nx.connected_components(graph))
    components_sorted = sorted(all_components, key=len, reverse=True)

    for i, comp_nodes in enumerate(components_sorted[:2], start=1):
        Gc = graph.subgraph(comp_nodes).copy()
            
        if Gc.number_of_nodes() >= 30:
            largest.append(Gc)
            print(f'Largest CC:{Gc}')

        else:
            print('Very Small')
# Out:
# Graph with 30299 nodes and 42301 edges
# Largest CC:Graph with 28122 nodes and 39314 edges
# Largest CC:Graph with 2177 nodes and 2987 edges
# Graph with 228661 nodes and 364703 edges
# Largest CC:Graph with 228653 nodes and 364699 edges
# Very Small
# Graph with 26371 nodes and 40243 edges
# Largest CC:Graph with 21029 nodes and 32223 edges
# Largest CC:Graph with 4359 nodes and 6603 edges
# Graph with 235088 nodes and 365332 edges
# Largest CC:Graph with 235088 nodes and 365332 edges
# Graph with 49771 nodes and 78151 edges
# Largest CC:Graph with 49771 nodes and 78151 edges
# Graph with 4255 nodes and 3754 edges
# Largest CC:Graph with 151 nodes and 150 edges
# Largest CC:Graph with 137 nodes and 136 edges
# Graph with 4303 nodes and 3694 edges
# Largest CC:Graph with 120 nodes and 119 edges
# Largest CC:Graph with 108 nodes and 107 edges
# Graph with 40347 nodes and 34928 edges
# Largest CC:Graph with 415 nodes and 414 edges
# Largest CC:Graph with 260 nodes and 259 edges
# Graph with 9954 nodes and 8617 edges
# Largest CC:Graph with 429 nodes and 430 edges
# Largest CC:Graph with 375 nodes and 376 edges
# Graph with 12709 nodes and 11018 edges
# Largest CC:Graph with 198 nodes and 197 edges
# Largest CC:Graph with 121 nodes and 120 edges
# Graph with 4567 nodes and 3994 edges
# Largest CC:Graph with 122 nodes and 121 edges
# Largest CC:Graph with 94 nodes and 93 edges
# Graph with 9869 nodes and 8451 edges
# Largest CC:Graph with 122 nodes and 121 edges
# Largest CC:Graph with 115 nodes and 114 edges
# Graph with 1262 nodes and 1093 edges
# Largest CC:Graph with 51 nodes and 50 edges
# Largest CC:Graph with 48 nodes and 47 edges
# Graph with 28925 nodes and 25267 edges
# Largest CC:Graph with 2520 nodes and 2556 edges
# Largest CC:Graph with 934 nodes and 952 edges
# Graph with 15928 nodes and 13257 edges
# Largest CC:Graph with 164 nodes and 163 edges
# Largest CC:Graph with 164 nodes and 163 edges
# Graph with 2721 nodes and 2313 edges
# Largest CC:Graph with 154 nodes and 153 edges
# Largest CC:Graph with 149 nodes and 148 edges
# Graph with 32157 nodes and 27645 edges
# Largest CC:Graph with 2152 nodes and 2177 edges
# Largest CC:Graph with 1480 nodes and 1511 edges
# Graph with 16168 nodes and 13516 edges
# Largest CC:Graph with 588 nodes and 593 edges
# Largest CC:Graph with 347 nodes and 349 edges
# Graph with 18355 nodes and 15921 edges
# Largest CC:Graph with 486 nodes and 485 edges
# Largest CC:Graph with 322 nodes and 323 edges
# Graph with 7155 nodes and 9801 edges
# Largest CC:Graph with 7155 nodes and 9801 edges
# Graph with 3482 nodes and 4996 edges
# Largest CC:Graph with 3479 nodes and 4994 edges
# Very Small
# Graph with 7082 nodes and 9537 edges
# Largest CC:Graph with 7075 nodes and 9531 edges
# Very Small
# Graph with 6955 nodes and 9570 edges
# Largest CC:Graph with 6951 nodes and 9567 edges
# Very Small
# Graph with 6479 nodes and 9034 edges
# Largest CC:Graph with 6469 nodes and 9027 edges
# Very Small
# Graph with 32093 nodes and 22356 edges
# Largest CC:Graph with 71 nodes and 78 edges
# Largest CC:Graph with 59 nodes and 60 edges
# Graph with 1639 nodes and 1621 edges
# Largest CC:Graph with 1373 nodes and 1441 edges
# Very Small
# Graph with 6089 nodes and 5105 edges
# Largest CC:Graph with 108 nodes and 108 edges
# Largest CC:Graph with 98 nodes and 98 edges
# Graph with 1330 nodes and 880 edges
# Very Small
# Very Small
# Graph with 1832 nodes and 1900 edges
# Largest CC:Graph with 1659 nodes and 1781 edges
# Very Small
# Graph with 129 nodes and 124 edges
# Largest CC:Graph with 113 nodes and 116 edges
# Very Small
# Graph with 220 nodes and 202 edges
# Largest CC:Graph with 126 nodes and 130 edges
# Largest CC:Graph with 35 nodes and 35 edges
# Graph with 359 nodes and 351 edges
# Largest CC:Graph with 241 nodes and 258 edges
# Largest CC:Graph with 42 nodes and 41 edges
# Graph with 264 nodes and 247 edges
# Largest CC:Graph with 134 nodes and 138 edges
# Very Small
# Graph with 220 nodes and 188 edges
# Largest CC:Graph with 65 nodes and 66 edges
# Largest CC:Graph with 45 nodes and 49 edges
# Graph with 214 nodes and 196 edges
# Largest CC:Graph with 112 nodes and 117 edges
# Very Small
# Graph with 152 nodes and 148 edges
# Largest CC:Graph with 124 nodes and 129 edges
# Very Small
# Graph with 1130 nodes and 1112 edges
# Largest CC:Graph with 417 nodes and 452 edges
# Largest CC:Graph with 311 nodes and 333 edges
# Graph with 6003 nodes and 5406 edges
# Largest CC:Graph with 202 nodes and 203 edges
# Largest CC:Graph with 116 nodes and 115 edges
# Graph with 3317 nodes and 4258 edges
# Largest CC:Graph with 3231 nodes and 4197 edges
# Very Small
# Graph with 36 nodes and 49 edges
# Largest CC:Graph with 36 nodes and 49 edges
# Graph with 36 nodes and 48 edges
# Largest CC:Graph with 36 nodes and 48 edges
# Graph with 30 nodes and 49 edges
# Largest CC:Graph with 30 nodes and 49 edges
# Graph with 2411 nodes and 2208 edges
# Largest CC:Graph with 936 nodes and 960 edges
# Largest CC:Graph with 199 nodes and 208 edges
# Graph with 4029 nodes and 3536 edges
# Largest CC:Graph with 165 nodes and 171 edges
# Largest CC:Graph with 162 nodes and 163 edges
# Graph with 2171 nodes and 1770 edges
# Largest CC:Graph with 43 nodes and 44 edges
# Largest CC:Graph with 40 nodes and 39 edges
# Graph with 2152 nodes and 2216 edges
# Largest CC:Graph with 539 nodes and 605 edges
# Largest CC:Graph with 449 nodes and 472 edges
# Graph with 1309 nodes and 897 edges
# Very Small
# Very Small
# Graph with 1513 nodes and 1358 edges
# Largest CC:Graph with 647 nodes and 660 edges
# Largest CC:Graph with 54 nodes and 53 edges
# Graph with 24 nodes and 30 edges
# Very Small
# Graph with 10819 nodes and 9395 edges
# Largest CC:Graph with 244 nodes and 246 edges
# Largest CC:Graph with 181 nodes and 194 edges
# Graph with 1238 nodes and 958 edges
# Largest CC:Graph with 58 nodes and 60 edges
# Very Small
# Graph with 230 nodes and 221 edges
# Largest CC:Graph with 61 nodes and 60 edges
# Largest CC:Graph with 47 nodes and 47 edges
# Graph with 122 nodes and 159 edges
# Largest CC:Graph with 122 nodes and 159 edges
# Graph with 60 nodes and 67 edges
# Largest CC:Graph with 60 nodes and 67 edges
# Graph with 43 nodes and 47 edges
# Largest CC:Graph with 43 nodes and 47 edges
# Graph with 43 nodes and 49 edges
# Largest CC:Graph with 43 nodes and 49 edges
# Graph with 102 nodes and 143 edges
# Largest CC:Graph with 102 nodes and 143 edges
# Graph with 81 nodes and 93 edges
# Largest CC:Graph with 81 nodes and 93 edges
# Graph with 187 nodes and 253 edges
# Largest CC:Graph with 187 nodes and 253 edges
# Graph with 144 nodes and 169 edges
# Largest CC:Graph with 144 nodes and 169 edges
# Graph with 155 nodes and 184 edges
# Largest CC:Graph with 150 nodes and 181 edges
# Very Small
# Graph with 29 nodes and 38 edges
# Very Small
# Graph with 117 nodes and 156 edges
# Largest CC:Graph with 117 nodes and 156 edges
# Graph with 2101 nodes and 2156 edges
# Largest CC:Graph with 1334 nodes and 1420 edges
# Largest CC:Graph with 316 nodes and 337 edges
# Graph with 36 nodes and 60 edges
# Largest CC:Graph with 36 nodes and 60 edges
# Graph with 24 nodes and 39 edges
# Very Small
# Graph with 146 nodes and 186 edges
# Largest CC:Graph with 146 nodes and 186 edges
# Graph with 10406 nodes and 9349 edges
# Largest CC:Graph with 175 nodes and 178 edges
# Largest CC:Graph with 147 nodes and 146 edges
# Graph with 3053 nodes and 2697 edges
# Largest CC:Graph with 675 nodes and 706 edges
# Largest CC:Graph with 95 nodes and 95 edges
# Graph with 2785 nodes and 2914 edges
# Largest CC:Graph with 2033 nodes and 2278 edges
# Largest CC:Graph with 205 nodes and 208 edges

# %%
#Export graph as pickle with attributes
for i, graph in enumerate(largest):
    output = f'data/tds_cc/G{i}.pickle'
    with open (output, 'wb') as f:
        pickle.dump(graph, f)

# %%
def graph_area(G):
    pos = nx.get_node_attributes(G, 'pos')
    xs = [p[0] for p in pos.values()]
    ys = [p[1] for p in pos.values()]

    width = max(xs) - min(xs)
    height = max(ys) - min(ys)

    return width*height

# %%
# Plot the fracture network as graphs
kwds = {
    'with_labels': False, 
    'node_shape': 'o',         # node symbol
    'node_color': 'blue',      # node color
    'edgecolors': 'black',     # node border color
    'node_size': 10,            # node size
    'linewidths': 0.2,         # node border width
    'edge_color': 'black',     # edge color
    'width': 1,                # edge width
    'font_size': 8,            # font size
    'font_color': 'black',      # font color
    'alpha': 0.6 ,              # transparency
}

cols = 4
rows = (len(largest) + cols -1) // cols
figsize = (4*cols, 4*rows)

fig, axes = plt.subplots(rows, cols, figsize=figsize)
axes = axes.flatten()

for i, G in enumerate(largest):
    ax = axes[i]
    plt.sca(ax)

    pos = nx.get_node_attributes(G, 'pos')

    if pos:
        nx.draw(G, pos=pos, **kwds)
        area = graph_area(G)
        ax.set_title(f'G{i} - Area: {area:.2f}')
        ax.axis('equal')
    else:
        (f'G{i} (no pos)')
        ax.axis('off')

#plt.savefig('fracgraphsTDS.png', transparent=True, dpi=300)
    
plt.show()

# %%
# Simplify graphs with karstnet
import karstnet as kn
simplo = []

for graph in graphs:
    print(f'Largest Connected Component: {graph}')
    graphk = kn.from_nxGraph(graph, dict(graph.nodes('pos')), verbose=True)
    K = graphk.graph_simpl
    print(f'Simple graph: {K}')
    nx.set_node_attributes(K, graphk.pos2d, 'pos')
    simplo.append(K)
# Out:
# Largest Connected Component: Graph with 30299 nodes and 42301 edges
#
#  This network contains  2  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 30299 nodes and 42301 edges
# Largest Connected Component: Graph with 228661 nodes and 364703 edges
#
#  This network contains  5  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 228661 nodes and 364703 edges
# Largest Connected Component: Graph with 26371 nodes and 40243 edges
#
#  This network contains  5  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 26371 nodes and 40243 edges
# Largest Connected Component: Graph with 235088 nodes and 365332 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 235088 nodes and 365332 edges
# Largest Connected Component: Graph with 49771 nodes and 78151 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 49771 nodes and 78151 edges
# Largest Connected Component: Graph with 4255 nodes and 3754 edges
#
#  This network contains  507  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 1471 nodes and 970 edges
# Largest Connected Component: Graph with 4303 nodes and 3694 edges
#
#  This network contains  611  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 1837 nodes and 1228 edges
# Largest Connected Component: Graph with 40347 nodes and 34928 edges
#
#  This network contains  5428  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 13946 nodes and 8527 edges
# Largest Connected Component: Graph with 9954 nodes and 8617 edges
#
#  This network contains  1344  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 3604 nodes and 2267 edges
# Largest Connected Component: Graph with 12709 nodes and 11018 edges
#
#  This network contains  1695  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 4261 nodes and 2570 edges
# Largest Connected Component: Graph with 4567 nodes and 3994 edges
#
#  This network contains  573  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 1429 nodes and 856 edges
# Largest Connected Component: Graph with 9869 nodes and 8451 edges
#
#  This network contains  1418  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 3592 nodes and 2174 edges
# Largest Connected Component: Graph with 1262 nodes and 1093 edges
#
#  This network contains  170  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 397 nodes and 228 edges
# Largest Connected Component: Graph with 28925 nodes and 25267 edges
#
#  This network contains  3821  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 14123 nodes and 10465 edges
# Largest Connected Component: Graph with 15928 nodes and 13257 edges
#
#  This network contains  2674  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 6763 nodes and 4092 edges
# Largest Connected Component: Graph with 2721 nodes and 2313 edges
#
#  This network contains  408  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 1062 nodes and 654 edges
# Largest Connected Component: Graph with 32157 nodes and 27645 edges
#
#  This network contains  4662  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 16049 nodes and 11537 edges
# Largest Connected Component: Graph with 16168 nodes and 13516 edges
#
#  This network contains  2699  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 8432 nodes and 5780 edges
# Largest Connected Component: Graph with 18355 nodes and 15921 edges
#
#  This network contains  2439  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 6366 nodes and 3932 edges
# Largest Connected Component: Graph with 7155 nodes and 9801 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 5143 nodes and 7789 edges
# Largest Connected Component: Graph with 3482 nodes and 4996 edges
#
#  This network contains  2  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 2808 nodes and 4322 edges
# Largest Connected Component: Graph with 7082 nodes and 9537 edges
#
#  This network contains  2  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 4425 nodes and 6880 edges
# Largest Connected Component: Graph with 6955 nodes and 9570 edges
#
#  This network contains  2  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 4476 nodes and 7091 edges
# Largest Connected Component: Graph with 6479 nodes and 9034 edges
#
#  This network contains  4  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 4415 nodes and 6970 edges
# Largest Connected Component: Graph with 32093 nodes and 22356 edges
#
#  This network contains  9903  connected components
# Warning: This network contains  7 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 25860 nodes and 16124 edges
# Largest Connected Component: Graph with 1639 nodes and 1621 edges
#
#  This network contains  87  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 1382 nodes and 1364 edges
# Largest Connected Component: Graph with 6089 nodes and 5105 edges
#
#  This network contains  989  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 2863 nodes and 1879 edges
# Largest Connected Component: Graph with 1330 nodes and 880 edges
#
#  This network contains  450  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 913 nodes and 463 edges
# Largest Connected Component: Graph with 1832 nodes and 1900 edges
#
#  This network contains  55  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 1396 nodes and 1464 edges
# Largest Connected Component: Graph with 129 nodes and 124 edges
#
#  This network contains  9  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 121 nodes and 116 edges
# Largest Connected Component: Graph with 220 nodes and 202 edges
#
#  This network contains  24  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 189 nodes and 171 edges
# Largest Connected Component: Graph with 359 nodes and 351 edges
#
#  This network contains  26  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 310 nodes and 302 edges
# Largest Connected Component: Graph with 264 nodes and 247 edges
#
#  This network contains  24  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 220 nodes and 203 edges
# Largest Connected Component: Graph with 220 nodes and 188 edges
#
#  This network contains  39  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 210 nodes and 178 edges
# Largest Connected Component: Graph with 214 nodes and 196 edges
#
#  This network contains  26  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 193 nodes and 175 edges
# Largest Connected Component: Graph with 152 nodes and 148 edges
#
#  This network contains  10  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 142 nodes and 138 edges
# Largest Connected Component: Graph with 1130 nodes and 1112 edges
#
#  This network contains  86  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 814 nodes and 796 edges
# Largest Connected Component: Graph with 6003 nodes and 5406 edges
#
#  This network contains  605  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 1522 nodes and 925 edges
# Largest Connected Component: Graph with 3317 nodes and 4258 edges
#
#  This network contains  27  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 2442 nodes and 3383 edges
# Largest Connected Component: Graph with 36 nodes and 49 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 20 nodes and 33 edges
# Largest Connected Component: Graph with 36 nodes and 48 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 24 nodes and 36 edges
# Largest Connected Component: Graph with 30 nodes and 49 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 26 nodes and 45 edges
# Largest Connected Component: Graph with 2411 nodes and 2208 edges
#
#  This network contains  249  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 1393 nodes and 1190 edges
# Largest Connected Component: Graph with 4029 nodes and 3536 edges
#
#  This network contains  517  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 1687 nodes and 1194 edges
# Largest Connected Component: Graph with 2171 nodes and 1770 edges
#
#  This network contains  424  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 1220 nodes and 819 edges
# Largest Connected Component: Graph with 2152 nodes and 2216 edges
#
#  This network contains  81  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 815 nodes and 879 edges
# Largest Connected Component: Graph with 1309 nodes and 897 edges
#
#  This network contains  412  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 925 nodes and 513 edges
# Largest Connected Component: Graph with 1513 nodes and 1358 edges
#
#  This network contains  171  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 1057 nodes and 902 edges
# Largest Connected Component: Graph with 24 nodes and 30 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 12 nodes and 18 edges
# Largest Connected Component: Graph with 10819 nodes and 9395 edges
#
#  This network contains  1505  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 5023 nodes and 3599 edges
# Largest Connected Component: Graph with 1238 nodes and 958 edges
#
#  This network contains  285  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 752 nodes and 472 edges
# Largest Connected Component: Graph with 230 nodes and 221 edges
#
#  This network contains  11  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 74 nodes and 65 edges
# Largest Connected Component: Graph with 122 nodes and 159 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 95 nodes and 132 edges
# Largest Connected Component: Graph with 60 nodes and 67 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 45 nodes and 52 edges
# Largest Connected Component: Graph with 43 nodes and 47 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 26 nodes and 30 edges
# Largest Connected Component: Graph with 43 nodes and 49 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 30 nodes and 36 edges
# Largest Connected Component: Graph with 102 nodes and 143 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 79 nodes and 120 edges
# Largest Connected Component: Graph with 81 nodes and 93 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 50 nodes and 62 edges
# Largest Connected Component: Graph with 187 nodes and 253 edges
#
#  This network contains  1  connected components
# Warning: This network contains  1 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 129 nodes and 195 edges
# Largest Connected Component: Graph with 144 nodes and 169 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 100 nodes and 125 edges
# Largest Connected Component: Graph with 155 nodes and 184 edges
#
#  This network contains  3  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 103 nodes and 132 edges
# Largest Connected Component: Graph with 29 nodes and 38 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 18 nodes and 27 edges
# Largest Connected Component: Graph with 117 nodes and 156 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 81 nodes and 120 edges
# Largest Connected Component: Graph with 2101 nodes and 2156 edges
#
#  This network contains  62  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 1106 nodes and 1161 edges
# Largest Connected Component: Graph with 36 nodes and 60 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 32 nodes and 56 edges
# Largest Connected Component: Graph with 24 nodes and 39 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 24 nodes and 39 edges
# Largest Connected Component: Graph with 146 nodes and 186 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 143 nodes and 183 edges
# Largest Connected Component: Graph with 10406 nodes and 9349 edges
#
#  This network contains  1100  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 3167 nodes and 2110 edges
# Largest Connected Component: Graph with 3053 nodes and 2697 edges
#
#  This network contains  436  connected components
# Warning: This network contains  1 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 1547 nodes and 1191 edges
# Largest Connected Component: Graph with 2785 nodes and 2914 edges
#
#  This network contains  125  connected components
# Warning: This network contains  1 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 1667 nodes and 1796 edges

# %%
#Export graph as pickle with attributes
for i, graph in enumerate(simplo):
    output = f'data/tds_simplo/G{i}.pickle'
    with open (output, 'wb') as f:
        pickle.dump(graph, f)

# %%
# Identify largest connected components from simplified graphs
largesto = []
for graph in simplo:
    print(graph)
    all_components = list(nx.connected_components(graph))
    components_sorted = sorted(all_components, key=len, reverse=True)

    for i, comp_nodes in enumerate(components_sorted[:5], start=1):
        Gc = graph.subgraph(comp_nodes).copy()
            
        if Gc.number_of_nodes() >= 30:
            largesto.append(Gc)
            print(f'Largest CC:{Gc}')

        else:
            print('Very Small')
# Out:
# Graph with 30299 nodes and 42301 edges
# Largest CC:Graph with 28122 nodes and 39314 edges
# Largest CC:Graph with 2177 nodes and 2987 edges
# Graph with 228661 nodes and 364703 edges
# Largest CC:Graph with 228653 nodes and 364699 edges
# Very Small
# Very Small
# Very Small
# Very Small
# Graph with 26371 nodes and 40243 edges
# Largest CC:Graph with 21029 nodes and 32223 edges
# Largest CC:Graph with 4359 nodes and 6603 edges
# Largest CC:Graph with 536 nodes and 773 edges
# Largest CC:Graph with 309 nodes and 435 edges
# Largest CC:Graph with 138 nodes and 209 edges
# Graph with 235088 nodes and 365332 edges
# Largest CC:Graph with 235088 nodes and 365332 edges
# Graph with 49771 nodes and 78151 edges
# Largest CC:Graph with 49771 nodes and 78151 edges
# Graph with 1471 nodes and 970 edges
# Very Small
# Very Small
# Very Small
# Very Small
# Very Small
# Graph with 1837 nodes and 1228 edges
# Largest CC:Graph with 38 nodes and 37 edges
# Largest CC:Graph with 36 nodes and 35 edges
# Largest CC:Graph with 32 nodes and 31 edges
# Very Small
# Very Small
# Graph with 13946 nodes and 8527 edges
# Largest CC:Graph with 84 nodes and 83 edges
# Largest CC:Graph with 46 nodes and 45 edges
# Largest CC:Graph with 43 nodes and 43 edges
# Largest CC:Graph with 41 nodes and 40 edges
# Largest CC:Graph with 41 nodes and 40 edges
# Graph with 3604 nodes and 2267 edges
# Largest CC:Graph with 93 nodes and 94 edges
# Largest CC:Graph with 85 nodes and 86 edges
# Very Small
# Very Small
# Very Small
# Graph with 4261 nodes and 2570 edges
# Largest CC:Graph with 30 nodes and 29 edges
# Very Small
# Very Small
# Very Small
# Very Small
# Graph with 1429 nodes and 856 edges
# Very Small
# Very Small
# Very Small
# Very Small
# Very Small
# Graph with 3592 nodes and 2174 edges
# Largest CC:Graph with 31 nodes and 30 edges
# Very Small
# Very Small
# Very Small
# Very Small
# Graph with 397 nodes and 228 edges
# Very Small
# Very Small
# Very Small
# Very Small
# Very Small
# Graph with 14123 nodes and 10465 edges
# Largest CC:Graph with 973 nodes and 1009 edges
# Largest CC:Graph with 381 nodes and 399 edges
# Largest CC:Graph with 373 nodes and 385 edges
# Largest CC:Graph with 313 nodes and 322 edges
# Largest CC:Graph with 292 nodes and 301 edges
# Graph with 6763 nodes and 4092 edges
# Largest CC:Graph with 53 nodes and 52 edges
# Largest CC:Graph with 41 nodes and 40 edges
# Largest CC:Graph with 40 nodes and 39 edges
# Very Small
# Very Small
# Graph with 1062 nodes and 654 edges
# Largest CC:Graph with 35 nodes and 34 edges
# Very Small
# Very Small
# Very Small
# Very Small
# Graph with 16049 nodes and 11537 edges
# Largest CC:Graph with 837 nodes and 862 edges
# Largest CC:Graph with 663 nodes and 694 edges
# Largest CC:Graph with 515 nodes and 533 edges
# Largest CC:Graph with 341 nodes and 348 edges
# Largest CC:Graph with 198 nodes and 200 edges
# Graph with 8432 nodes and 5780 edges
# Largest CC:Graph with 224 nodes and 229 edges
# Largest CC:Graph with 142 nodes and 142 edges
# Largest CC:Graph with 116 nodes and 117 edges
# Largest CC:Graph with 100 nodes and 102 edges
# Largest CC:Graph with 76 nodes and 79 edges
# Graph with 6366 nodes and 3932 edges
# Largest CC:Graph with 84 nodes and 83 edges
# Largest CC:Graph with 55 nodes and 56 edges
# Largest CC:Graph with 42 nodes and 42 edges
# Largest CC:Graph with 40 nodes and 40 edges
# Largest CC:Graph with 37 nodes and 36 edges
# Graph with 5143 nodes and 7789 edges
# Largest CC:Graph with 5143 nodes and 7789 edges
# Graph with 2808 nodes and 4322 edges
# Largest CC:Graph with 2806 nodes and 4321 edges
# Very Small
# Graph with 4425 nodes and 6880 edges
# Largest CC:Graph with 4420 nodes and 6876 edges
# Very Small
# Graph with 4476 nodes and 7091 edges
# Largest CC:Graph with 4474 nodes and 7090 edges
# Very Small
# Graph with 4415 nodes and 6970 edges
# Largest CC:Graph with 4405 nodes and 6963 edges
# Very Small
# Very Small
# Very Small
# Graph with 25860 nodes and 16124 edges
# Largest CC:Graph with 62 nodes and 69 edges
# Largest CC:Graph with 49 nodes and 50 edges
# Largest CC:Graph with 45 nodes and 55 edges
# Largest CC:Graph with 44 nodes and 44 edges
# Largest CC:Graph with 44 nodes and 43 edges
# Graph with 1382 nodes and 1364 edges
# Largest CC:Graph with 1142 nodes and 1210 edges
# Very Small
# Very Small
# Very Small
# Very Small
# Graph with 2863 nodes and 1879 edges
# Largest CC:Graph with 48 nodes and 48 edges
# Very Small
# Very Small
# Very Small
# Very Small
# Graph with 913 nodes and 463 edges
# Very Small
# Very Small
# Very Small
# Very Small
# Very Small
# Graph with 1396 nodes and 1464 edges
# Largest CC:Graph with 1249 nodes and 1371 edges
# Very Small
# Very Small
# Very Small
# Very Small
# Graph with 121 nodes and 116 edges
# Largest CC:Graph with 105 nodes and 108 edges
# Very Small
# Very Small
# Very Small
# Very Small
# Graph with 189 nodes and 171 edges
# Largest CC:Graph with 103 nodes and 107 edges
# Largest CC:Graph with 30 nodes and 30 edges
# Very Small
# Very Small
# Very Small
# Graph with 310 nodes and 302 edges
# Largest CC:Graph with 200 nodes and 217 edges
# Largest CC:Graph with 38 nodes and 37 edges
# Very Small
# Very Small
# Very Small
# Graph with 220 nodes and 203 edges
# Largest CC:Graph with 106 nodes and 110 edges
# Very Small
# Very Small
# Very Small
# Very Small
# Graph with 210 nodes and 178 edges
# Largest CC:Graph with 58 nodes and 59 edges
# Largest CC:Graph with 43 nodes and 47 edges
# Very Small
# Very Small
# Very Small
# Graph with 193 nodes and 175 edges
# Largest CC:Graph with 99 nodes and 104 edges
# Very Small
# Very Small
# Very Small
# Very Small
# Graph with 142 nodes and 138 edges
# Largest CC:Graph with 115 nodes and 120 edges
# Very Small
# Very Small
# Very Small
# Very Small
# Graph with 814 nodes and 796 edges
# Largest CC:Graph with 289 nodes and 324 edges
# Largest CC:Graph with 211 nodes and 233 edges
# Largest CC:Graph with 36 nodes and 37 edges
# Very Small
# Very Small
# Graph with 1522 nodes and 925 edges
# Largest CC:Graph with 64 nodes and 65 edges
# Very Small
# Very Small
# Very Small
# Very Small
# Graph with 2442 nodes and 3383 edges
# Largest CC:Graph with 2374 nodes and 3340 edges
# Very Small
# Very Small
# Very Small
# Very Small
# Graph with 20 nodes and 33 edges
# Very Small
# Graph with 24 nodes and 36 edges
# Very Small
# Graph with 26 nodes and 45 edges
# Very Small
# Graph with 1393 nodes and 1190 edges
# Largest CC:Graph with 466 nodes and 490 edges
# Largest CC:Graph with 102 nodes and 111 edges
# Largest CC:Graph with 38 nodes and 42 edges
# Largest CC:Graph with 37 nodes and 40 edges
# Very Small
# Graph with 1687 nodes and 1194 edges
# Largest CC:Graph with 54 nodes and 60 edges
# Largest CC:Graph with 38 nodes and 39 edges
# Largest CC:Graph with 32 nodes and 31 edges
# Very Small
# Very Small
# Graph with 1220 nodes and 819 edges
# Very Small
# Very Small
# Very Small
# Very Small
# Very Small
# Graph with 815 nodes and 879 edges
# Largest CC:Graph with 200 nodes and 266 edges
# Largest CC:Graph with 155 nodes and 196 edges
# Largest CC:Graph with 140 nodes and 163 edges
# Largest CC:Graph with 67 nodes and 74 edges
# Very Small
# Graph with 925 nodes and 513 edges
# Very Small
# Very Small
# Very Small
# Very Small
# Very Small
# Graph with 1057 nodes and 902 edges
# Largest CC:Graph with 435 nodes and 448 edges
# Largest CC:Graph with 38 nodes and 37 edges
# Very Small
# Very Small
# Very Small
# Graph with 12 nodes and 18 edges
# Very Small
# Graph with 5023 nodes and 3599 edges
# Largest CC:Graph with 112 nodes and 114 edges
# Largest CC:Graph with 110 nodes and 117 edges
# Largest CC:Graph with 102 nodes and 115 edges
# Largest CC:Graph with 89 nodes and 95 edges
# Largest CC:Graph with 42 nodes and 42 edges
# Graph with 752 nodes and 472 edges
# Largest CC:Graph with 30 nodes and 32 edges
# Very Small
# Very Small
# Very Small
# Very Small
# Graph with 74 nodes and 65 edges
# Very Small
# Very Small
# Very Small
# Very Small
# Very Small
# Graph with 95 nodes and 132 edges
# Largest CC:Graph with 95 nodes and 132 edges
# Graph with 45 nodes and 52 edges
# Largest CC:Graph with 45 nodes and 52 edges
# Graph with 26 nodes and 30 edges
# Very Small
# Graph with 30 nodes and 36 edges
# Largest CC:Graph with 30 nodes and 36 edges
# Graph with 79 nodes and 120 edges
# Largest CC:Graph with 79 nodes and 120 edges
# Graph with 50 nodes and 62 edges
# Largest CC:Graph with 50 nodes and 62 edges
# Graph with 129 nodes and 195 edges
# Largest CC:Graph with 129 nodes and 195 edges
# Graph with 100 nodes and 125 edges
# Largest CC:Graph with 100 nodes and 125 edges
# Graph with 103 nodes and 132 edges
# Largest CC:Graph with 99 nodes and 130 edges
# Very Small
# Very Small
# Graph with 18 nodes and 27 edges
# Very Small
# Graph with 81 nodes and 120 edges
# Largest CC:Graph with 81 nodes and 120 edges
# Graph with 1106 nodes and 1161 edges
# Largest CC:Graph with 684 nodes and 770 edges
# Largest CC:Graph with 168 nodes and 189 edges
# Largest CC:Graph with 38 nodes and 43 edges
# Very Small
# Very Small
# Graph with 32 nodes and 56 edges
# Largest CC:Graph with 32 nodes and 56 edges
# Graph with 24 nodes and 39 edges
# Very Small
# Graph with 143 nodes and 183 edges
# Largest CC:Graph with 143 nodes and 183 edges
# Graph with 3167 nodes and 2110 edges
# Largest CC:Graph with 51 nodes and 54 edges
# Very Small
# Very Small
# Very Small
# Very Small
# Graph with 1547 nodes and 1191 edges
# Largest CC:Graph with 261 nodes and 292 edges
# Largest CC:Graph with 45 nodes and 45 edges
# Largest CC:Graph with 37 nodes and 38 edges
# Largest CC:Graph with 36 nodes and 39 edges
# Largest CC:Graph with 35 nodes and 41 edges
# Graph with 1667 nodes and 1796 edges
# Largest CC:Graph with 1207 nodes and 1452 edges
# Largest CC:Graph with 99 nodes and 102 edges
# Very Small
# Very Small
# Very Small

# %%
#Export graph as pickle with attributes
for i, graph in enumerate(largesto):
    output = f'data/tds_simplo_largesto/G{i}.pickle'
    with open (output, 'wb') as f:
        pickle.dump(graph, f)

# %%
# Simplify graphs with karstnet
import karstnet as kn
simple = []

for graph in largest:
    print(f'Largest Connected Component: {graph}')
    graphk = kn.from_nxGraph(graph, dict(graph.nodes('pos')), verbose=True)
    K = graphk.graph_simpl
    print(f'Simple graph: {K}')
    nx.set_node_attributes(K, graphk.pos2d, 'pos')
    simple.append(K)
# Out:
# Largest Connected Component: Graph with 28122 nodes and 39314 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 28122 nodes and 39314 edges
# Largest Connected Component: Graph with 2177 nodes and 2987 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 2177 nodes and 2987 edges
# Largest Connected Component: Graph with 228653 nodes and 364699 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 228653 nodes and 364699 edges
# Largest Connected Component: Graph with 21029 nodes and 32223 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 21029 nodes and 32223 edges
# Largest Connected Component: Graph with 4359 nodes and 6603 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 4359 nodes and 6603 edges
# Largest Connected Component: Graph with 235088 nodes and 365332 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 235088 nodes and 365332 edges
# Largest Connected Component: Graph with 49771 nodes and 78151 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 49771 nodes and 78151 edges
# Largest Connected Component: Graph with 151 nodes and 150 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 15 nodes and 14 edges
# Largest Connected Component: Graph with 137 nodes and 136 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 14 nodes and 13 edges
# Largest Connected Component: Graph with 120 nodes and 119 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 36 nodes and 35 edges
# Largest Connected Component: Graph with 108 nodes and 107 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 32 nodes and 31 edges
# Largest Connected Component: Graph with 415 nodes and 414 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 84 nodes and 83 edges
# Largest Connected Component: Graph with 260 nodes and 259 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 36 nodes and 35 edges
# Largest Connected Component: Graph with 429 nodes and 430 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 93 nodes and 94 edges
# Largest Connected Component: Graph with 375 nodes and 376 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 85 nodes and 86 edges
# Largest Connected Component: Graph with 198 nodes and 197 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 30 nodes and 29 edges
# Largest Connected Component: Graph with 121 nodes and 120 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 14 nodes and 13 edges
# Largest Connected Component: Graph with 122 nodes and 121 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 14 nodes and 13 edges
# Largest Connected Component: Graph with 94 nodes and 93 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 11 nodes and 10 edges
# Largest Connected Component: Graph with 122 nodes and 121 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 23 nodes and 22 edges
# Largest Connected Component: Graph with 115 nodes and 114 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 27 nodes and 26 edges
# Largest Connected Component: Graph with 51 nodes and 50 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 4 nodes and 3 edges
# Largest Connected Component: Graph with 48 nodes and 47 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 10 nodes and 9 edges
# Largest Connected Component: Graph with 2520 nodes and 2556 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 973 nodes and 1009 edges
# Largest Connected Component: Graph with 934 nodes and 952 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 381 nodes and 399 edges
# Largest Connected Component: Graph with 164 nodes and 163 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 40 nodes and 39 edges
# Largest Connected Component: Graph with 164 nodes and 163 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 53 nodes and 52 edges
# Largest Connected Component: Graph with 154 nodes and 153 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 35 nodes and 34 edges
# Largest Connected Component: Graph with 149 nodes and 148 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 25 nodes and 24 edges
# Largest Connected Component: Graph with 2152 nodes and 2177 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 837 nodes and 862 edges
# Largest Connected Component: Graph with 1480 nodes and 1511 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 663 nodes and 694 edges
# Largest Connected Component: Graph with 588 nodes and 593 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 224 nodes and 229 edges
# Largest Connected Component: Graph with 347 nodes and 349 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 100 nodes and 102 edges
# Largest Connected Component: Graph with 486 nodes and 485 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 84 nodes and 83 edges
# Largest Connected Component: Graph with 322 nodes and 323 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 55 nodes and 56 edges
# Largest Connected Component: Graph with 7155 nodes and 9801 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 5143 nodes and 7789 edges
# Largest Connected Component: Graph with 3479 nodes and 4994 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 2806 nodes and 4321 edges
# Largest Connected Component: Graph with 7075 nodes and 9531 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 4420 nodes and 6876 edges
# Largest Connected Component: Graph with 6951 nodes and 9567 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 4474 nodes and 7090 edges
# Largest Connected Component: Graph with 6469 nodes and 9027 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 4405 nodes and 6963 edges
# Largest Connected Component: Graph with 71 nodes and 78 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 62 nodes and 69 edges
# Largest Connected Component: Graph with 59 nodes and 60 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 49 nodes and 50 edges
# Largest Connected Component: Graph with 1373 nodes and 1441 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 1142 nodes and 1210 edges
# Largest Connected Component: Graph with 108 nodes and 108 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 28 nodes and 28 edges
# Largest Connected Component: Graph with 98 nodes and 98 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 48 nodes and 48 edges
# Largest Connected Component: Graph with 1659 nodes and 1781 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 1249 nodes and 1371 edges
# Largest Connected Component: Graph with 113 nodes and 116 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 105 nodes and 108 edges
# Largest Connected Component: Graph with 126 nodes and 130 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 103 nodes and 107 edges
# Largest Connected Component: Graph with 35 nodes and 35 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 30 nodes and 30 edges
# Largest Connected Component: Graph with 241 nodes and 258 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 200 nodes and 217 edges
# Largest Connected Component: Graph with 42 nodes and 41 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 38 nodes and 37 edges
# Largest Connected Component: Graph with 134 nodes and 138 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 106 nodes and 110 edges
# Largest Connected Component: Graph with 65 nodes and 66 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 58 nodes and 59 edges
# Largest Connected Component: Graph with 45 nodes and 49 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 43 nodes and 47 edges
# Largest Connected Component: Graph with 112 nodes and 117 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 99 nodes and 104 edges
# Largest Connected Component: Graph with 124 nodes and 129 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 115 nodes and 120 edges
# Largest Connected Component: Graph with 417 nodes and 452 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 289 nodes and 324 edges
# Largest Connected Component: Graph with 311 nodes and 333 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 211 nodes and 233 edges
# Largest Connected Component: Graph with 202 nodes and 203 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 64 nodes and 65 edges
# Largest Connected Component: Graph with 116 nodes and 115 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 23 nodes and 22 edges
# Largest Connected Component: Graph with 3231 nodes and 4197 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 2374 nodes and 3340 edges
# Largest Connected Component: Graph with 36 nodes and 49 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 20 nodes and 33 edges
# Largest Connected Component: Graph with 36 nodes and 48 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 24 nodes and 36 edges
# Largest Connected Component: Graph with 30 nodes and 49 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 26 nodes and 45 edges
# Largest Connected Component: Graph with 936 nodes and 960 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 466 nodes and 490 edges
# Largest Connected Component: Graph with 199 nodes and 208 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 102 nodes and 111 edges
# Largest Connected Component: Graph with 165 nodes and 171 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 54 nodes and 60 edges
# Largest Connected Component: Graph with 162 nodes and 163 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 38 nodes and 39 edges
# Largest Connected Component: Graph with 43 nodes and 44 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 25 nodes and 26 edges
# Largest Connected Component: Graph with 40 nodes and 39 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 2 nodes and 1 edges
# Largest Connected Component: Graph with 539 nodes and 605 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 200 nodes and 266 edges
# Largest Connected Component: Graph with 449 nodes and 472 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 140 nodes and 163 edges
# Largest Connected Component: Graph with 647 nodes and 660 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 435 nodes and 448 edges
# Largest Connected Component: Graph with 54 nodes and 53 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 38 nodes and 37 edges
# Largest Connected Component: Graph with 244 nodes and 246 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 112 nodes and 114 edges
# Largest Connected Component: Graph with 181 nodes and 194 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 102 nodes and 115 edges
# Largest Connected Component: Graph with 58 nodes and 60 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 30 nodes and 32 edges
# Largest Connected Component: Graph with 61 nodes and 60 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 18 nodes and 17 edges
# Largest Connected Component: Graph with 47 nodes and 47 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 20 nodes and 20 edges
# Largest Connected Component: Graph with 122 nodes and 159 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 95 nodes and 132 edges
# Largest Connected Component: Graph with 60 nodes and 67 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 45 nodes and 52 edges
# Largest Connected Component: Graph with 43 nodes and 47 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 26 nodes and 30 edges
# Largest Connected Component: Graph with 43 nodes and 49 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 30 nodes and 36 edges
# Largest Connected Component: Graph with 102 nodes and 143 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 79 nodes and 120 edges
# Largest Connected Component: Graph with 81 nodes and 93 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 50 nodes and 62 edges
# Largest Connected Component: Graph with 187 nodes and 253 edges
#
#  This network contains  1  connected components
# Warning: This network contains  1 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 129 nodes and 195 edges
# Largest Connected Component: Graph with 144 nodes and 169 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 100 nodes and 125 edges
# Largest Connected Component: Graph with 150 nodes and 181 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 99 nodes and 130 edges
# Largest Connected Component: Graph with 117 nodes and 156 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 81 nodes and 120 edges
# Largest Connected Component: Graph with 1334 nodes and 1420 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 684 nodes and 770 edges
# Largest Connected Component: Graph with 316 nodes and 337 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 168 nodes and 189 edges
# Largest Connected Component: Graph with 36 nodes and 60 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 32 nodes and 56 edges
# Largest Connected Component: Graph with 146 nodes and 186 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 143 nodes and 183 edges
# Largest Connected Component: Graph with 175 nodes and 178 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 51 nodes and 54 edges
# Largest Connected Component: Graph with 147 nodes and 146 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 18 nodes and 17 edges
# Largest Connected Component: Graph with 675 nodes and 706 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 261 nodes and 292 edges
# Largest Connected Component: Graph with 95 nodes and 95 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 45 nodes and 45 edges
# Largest Connected Component: Graph with 2033 nodes and 2278 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 1207 nodes and 1452 edges
# Largest Connected Component: Graph with 205 nodes and 208 edges
#
#  This network contains  1  connected components
# Warning: This network contains  0 looping branche.s Tortuosity is infinite on a looping branch. The looping branches are not considered for the mean tortuosity computation
#
# Simple graph: Graph with 99 nodes and 102 edges

# %%
#Export graph as pickle with attributes
for i, graph in enumerate(simple):
    output = f'data/tds_cc_simple/G{i}.pickle'
    with open (output, 'wb') as f:
        pickle.dump(graph, f)

# %%
# Plot the fracture network as graphs
kwds = {
    'with_labels': False, 
    'node_shape': 'o',         # node symbol
    'node_color': 'blue',      # node color
    'edgecolors': 'black',     # node border color
    'node_size': 10,            # node size
    'linewidths': 0.2,         # node border width
    'edge_color': 'black',     # edge color
    'width': 1,                # edge width
    'font_size': 8,            # font size
    'font_color': 'black',      # font color
    'alpha': 0.6 ,              # transparency
}

cols = 4
rows = (len(largesto) + cols -1) // cols
figsize = (4*cols, 4*rows)

fig, axes = plt.subplots(rows, cols, figsize=figsize)
axes = axes.flatten()

for i, G in enumerate(largesto):
    ax = axes[i]
    plt.sca(ax)

    pos = nx.get_node_attributes(G, 'pos')

    if pos:
        nx.draw(G, pos=pos, **kwds)
        area = graph_area(G)
        ax.set_title(f'G{i} - Area: {area:.2f}')
        ax.axis('equal')
    else:
        (f'G{i} (no pos)')
        ax.axis('off')

#plt.savefig('fracgraphsTDS.png', transparent=True, dpi=300)
    
plt.show()

# %%
import math
# Calculate lengths from graph edges
def lengths(graph):
    pos = nx.get_node_attributes(graph, 'pos')

    for u, v in graph.edges():
        x1, y1 = pos[u]
        x2, y2 = pos[v]
        
        length = math.sqrt((x2 - x1) ** 2 + (y2 - y1) ** 2)
        graph[u][v]['length'] = round(length, 3)

# %%
# Calculate azimuths from graph edges
def azimuths(graph):
    pos = nx.get_node_attributes(graph, 'pos')
    for u, v in graph.edges():
        x1, y1 = pos[u]
        x2, y2 = pos[v]
        
        # Calculate the angle between the edge and the positive y-axis
        angle_radians = math.atan2(x2 - x1, y2 - y1)
        graph[u][v]['rad'] = round(angle_radians, 2)
        
        angle_degrees = math.degrees(angle_radians)
        azimuth = (angle_degrees + 360) % 360
        graph[u][v]['azimuth'] = round(azimuth, 2)

# %%
# Define sets from azimuth
def sets(azimuth):
    if (0 <= azimuth < 15) or (165 <= azimuth <= 180):
        return 'NS'
    elif 15 <= azimuth < 30:
        return 'NNE-SSW'
    elif 30 <= azimuth < 45:
        return 'NE-SW'
    elif 45 <= azimuth < 60:
        return 'NE-SW'
    elif 60 <= azimuth < 75:
        return 'ENE-WSW'
    elif 75 <= azimuth < 90:
        return 'E-W'
    elif 90 <= azimuth < 105:
        return 'E-W'
    elif 105 <= azimuth < 120:
        return 'ESE-WNW'
    elif 120 <= azimuth < 135:
        return 'SE-NW'
    elif 135 <= azimuth < 150:
        return 'SE-NWW'
    elif 150 <= azimuth < 165:
        return 'SSE-NNW'
    else:
        return 'Undefined'

# %%
for graph in largesto:
    lengths(graph)
    azimuths(graph)

# %%
# Assign family labels to edges based on the set definition
for graph in largesto:
    for u, v, data in graph.edges(data=True):
        azimuth = data['azimuth']
        if azimuth > 180:
            azimuth = azimuth -180
        family = sets(azimuth)
        data['family'] = family

# %%
#Export graph as pickle with attributes
for i, graph in enumerate(largesto):
    output = f'data/tds_simplo_largesto_att/G{i}.pickle'
    with open (output, 'wb') as f:
        pickle.dump(graph, f)
